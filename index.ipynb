# %% [markdown]
# # K-Nearest Neighbors - Lab
#
# ## Introduction
#
# In this lesson, you'll build a simple version of a **_K-Nearest Neigbors classifier_** from scratch, and train it to make predictions on a dataset!
#
# ## Objectives
#
# In this lab you will:
#
# * Implement a basic KNN algorithm from scratch
#
# ## Getting Started
#
# You'll begin this lab by creating a classifier. To keep things simple, you'll be using a helper function, `euclidean()`, from the `spatial.distance` module of the `scipy` library. Import this function in the cell below:

# %%
from scipy.spatial.distance import euclidean
import numpy as np

# %% [markdown]
# ## Create the `KNN` class

# %% [markdown]
# You will now:
#
# * Create an class called `KNN`
# * This class should contain two empty methods -- `fit` and `predict`

# %%
# Define the KNN class with two empty methods - fit and predict
class KNN:
    def __init__(self, k=3):
        self.k = k
        self.X_train = None
        self.y_train = None

# %% [markdown]
# ## Comple the `fit()` method
#
# Recall that when "fitting" a KNN classifier, all you're really doing is storing the points and their corresponding labels. There's no actual "fitting" involved here, since all you need to do is store the data so that you can use it to calculate the nearest neighbors when the `predict()` method is called.
#
# The inputs for this function should be:
#
# * `self`: since this will be an instance method inside the `KNN` class
# * `X_train`: an array, each row represents a _vector_ for a given point in space
# * `y_train`: the corresponding labels for each vector in `X_train`. The label at `y_train[0]` is the label that corresponds to the vector at `X_train[0]`, and so on
#
# In the cell below, complete the `fit` method:

# %%
def fit(self, X_train, y_train):
    self.X_train = X_train
    self.y_train = y_train

    
# This line updates the knn.fit method to point to the function you've just written
KNN.fit = fit

# %% [markdown]
# ### Helper functions
#
# Next, you will write three helper functions to make things easier when completing the `predict()` method.
#
# In the cell below, complete the `_get_distances()` function. This function should:
#
# * Take in two arguments: `self` and `x`
# * Create an empty array, `distances`, to hold all the distances you're going to calculate
# * Enumerate through every item in `self.X_train`. For each item:
#     * Use the `euclidean()` function to get the distance between x and the current point from `X_train`
#     * Create a tuple containing the index and the distance (in that order!) and append it to the `distances` array
# * Return the `distances` array when a distance has been generated for all items in `self.X_train`

# %%
def _get_distances(self, x):
    distances = []
    for index, point in enumerate(self.X_train):
        dist = euclidean(x, point)
        print(f"Distance to train[{index}]: {dist}")  # Debug line
        distances.append((index, dist))
    return distances

# This line attaches the function you just created as a method to KNN class 
KNN._get_distances = _get_distances

# %% [markdown]
# Well done! You will now create a `_get_k_nearest()` function to retrieve indices of the k-nearest points. This function should:
#
# * Take three arguments:
#     * `self`
#     * `dists`: an array of tuples containing (index, distance), which will be output from the `_get_distances()` method.
#     * `k`: the number of nearest neighbors you want to return
# * Sort the `dists` array by distances values, which are the second element in each tuple
# * Return the first `k` tuples from the sorted array
#
# **_Hint:_** To easily sort on the second item in the tuples contained within the `dists` array, use the `sorted()` function and pass in lambda for the `key=` parameter. To sort on the second element of each tuple, you can just use `key=lambda x: x[1]`!

# %%
def _get_k_nearest(self, dists, k):
    sorted_dists = sorted(dists, key=lambda x: x[1])
    nearest = sorted_dists[:k]
    print("K-nearest:", nearest) 
    return nearest
    

# This line attaches the function you just created as a method to KNN class 
KNN._get_k_nearest = _get_k_nearest

# %% [markdown]
# The final helper function you'll create will get the labels that correspond to each of the k-nearest point, and return the class that occurs the most.
#
# Complete the `_get_label_prediction()` function in the cell below. This function should:
#
# * Create a list containing the labels from `self.y_train` for each index in `k_nearest` (remember, each item in `k_nearest` is a tuple, and the index is stored as the first item in each tuple)
# * Get the total counts for each label (use `np.bincount()` and pass in the label array created in the previous step)
# * Get the index of the label with the highest overall count in counts (use `np.argmax()` for this, and pass in the counts created in the previous step)

# %%
def _get_label_prediction(self, k_nearest):
        labels = [self.y_train[index] for index, _ in k_nearest]
        print("Nearest Labels:", labels)
        counts = np.bincount(labels)
        print("Counts:", counts)
        return np.argmax(counts)
    

# This line attaches the function you just created as a method to KNN class
KNN._get_label_prediction = _get_label_prediction

# %% [markdown]
# Great! Now, you now have all the ingredients needed to complete the `predict()` method.
#
# ## Complete the `predict()` method
#
# This method does all the heavy lifting for KNN, so this will be a bit more complex than the `fit()` method. Here's an outline of how this method should work:
#
# * In addition to `self`, our `predict` function should take in two arguments:
#     * `X_test`: the points we want to classify
#     * `k`: which specifies the number of neighbors we should use to make the classification.  Set `k=3` as a default, but allow the user to update it if they choose
# * Your method will need to iterate through every item in `X_test`. For each item:
#     * Calculate the distance to all points in `X_train` by using the `._get_distances()` helper method
#     * Find the k-nearest points in `X_train` by using the `._get_k_nearest()` method
#     * Use the index values contained within the tuples returned by `._get_k_nearest()` method to get the corresponding labels for each of the nearest points
#     * Determine which class is most represented in these labels and treat that as the prediction for this point. Append the prediction to `preds`
# * Once a prediction has been generated for every item in `X_test`, return `preds`
#
# Follow these instructions to complete the `predict()` method in the cell below:

# %%
def predict(self, X_test, k=None):
        if k is None:
            k = self.k 

        preds = []
        for x in X_test:
            dists = self._get_distances(x)
            k_nearest = self._get_k_nearest(dists, k)
            prediction = self._get_label_prediction(k_nearest)
            preds.append(prediction)
        return preds
    

# This line updates the knn.predict method to point to the function you've just written
KNN.predict = predict

# %% [markdown]
# Great! Now, try out your new KNN classifier on a sample dataset to see how well it works!
#
# ## Test the KNN classifier
#
# In order to test the performance of your model, import the **_Iris dataset_**. Specifically:
#
# - Use the `load_iris()` function, which can be found inside of the `sklearn.datasets` module. Then call this function, and use the object it returns
# - Import `train_test_split()` from `sklearn.model_selection`, as well as `accuracy_score()` from `sklearn.metrics`
# - Assign the `.data` attribute of `iris` to `data` and the `.target` attribute to `target`
#
# Note that there are **_3 classes_** in the Iris dataset, making this a multi-categorical classification problem. This means that you can't use evaluation metrics that are meant for binary classification problems. For this, just stick to accuracy for now.

# %%
# Import the necessary functions
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


iris = load_iris()
data = iris.data
target = iris.target

# %% [markdown]
# Use `train_test_split()` to split the data into training and test sets. Pass in the `data` and `target`, and set the `test_size` to 0.25 and `random_state` to 0.

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.25, random_state=0)

# %% [markdown]
# Now, instantiate the `KNN` class, and `fit` it to the data in `X_train` and the labels in `y_train`.

# %%
# Instantiate and fit KNN
knn = KNN(k=3)
knn.fit(X_train, y_train)

# %% [markdown]
# In the cell below, use the `.predict()` method to generate predictions for the data stored in `X_test`:

# %%
# Generate predictions
preds = knn.predict(X_test)
# Out:
# Distance to train[0]: 1.2922847983320083
# Distance to train[1]: 1.640121946685672
# Distance to train[2]: 1.1357816691600549
# Distance to train[3]: 4.5442271070007045
# Distance to train[4]: 1.1445523142259602
# Distance to train[5]: 4.076763422127901
# Distance to train[6]: 4.332435804486893
# Distance to train[7]: 2.408318915758459
# Distance to train[8]: 1.0246950765959602
# Distance to train[9]: 1.1958260743101403
# Distance to train[10]: 1.1045361017187258
# Distance to train[11]: 1.3228756555322956
# Distance to train[12]: 1.8055470085267786
# Distance to train[13]: 2.1587033144922905
# Distance to train[14]: 1.1401754250991376
# Distance to train[15]: 1.9052558883257649
# Distance to train[16]: 0.8124038404635957
# Distance to train[17]: 1.0295630140987
# Distance to train[18]: 1.322875655532295
# Distance to train[19]: 0.7745966692414833
# Distance to train[20]: 1.661324772583615
# Distance to train[21]: 0.8366600265340757
# Distance to train[22]: 1.1832159566199232
# Distance to train[23]: 4.263801121065568
# Distance to train[24]: 0.5099019513592784
# Distance to train[25]: 1.4387494569938155
# Distance to train[26]: 1.8734993995195193
# Distance to train[27]: 1.6124515496597096
# Distance to train[28]: 1.174734012447073
# Distance to train[29]: 1.813835714721706
# Distance to train[30]: 4.342810150121692
# Distance to train[31]: 4.8559242168715935
# Distance to train[32]: 0.8124038404635965
# Distance to train[33]: 1.5165750888103098
# Distance to train[34]: 4.113392760240626
# Distance to train[35]: 4.41927595879687
# Distance to train[36]: 1.4662878298615183
# Distance to train[37]: 4.396589587396121
# Distance to train[38]: 0.6403124237432849
# Distance to train[39]: 2.5845695966640165
# Distance to train[40]: 4.460941604639093
# Distance to train[41]: 1.2999999999999996
# Distance to train[42]: 1.9000000000000004
# Distance to train[43]: 1.4282856857085697
# Distance to train[44]: 4.474371464239418
# Distance to train[45]: 1.5684387141358125
# Distance to train[46]: 1.3190905958272927
# Distance to train[47]: 1.0295630140987002
# Distance to train[48]: 0.8366600265340759
# Distance to train[49]: 4.310452412450461
# Distance to train[50]: 4.295346318982906
# Distance to train[51]: 0.9000000000000002
# Distance to train[52]: 1.2288205727444512
# Distance to train[53]: 4.559605246071198
# Distance to train[54]: 0.7874007874011816
# Distance to train[55]: 4.402272140611027
# Distance to train[56]: 0.5196152422706629
# Distance to train[57]: 1.2165525060596445
# Distance to train[58]: 4.62601340248815
# Distance to train[59]: 4.450842616853577
# Distance to train[60]: 1.7691806012954134
# Distance to train[61]: 4.368065933568311
# Distance to train[62]: 4.613025037868318
# Distance to train[63]: 4.114608122288197
# Distance to train[64]: 1.6613247725836147
# Distance to train[65]: 1.3453624047073716
# Distance to train[66]: 2.370653918225939
# Distance to train[67]: 4.417012565071555
# Distance to train[68]: 4.32434966208793
# Distance to train[69]: 4.38748219369606
# Distance to train[70]: 1.2569805089976531
# Distance to train[71]: 1.4730919862656233
# Distance to train[72]: 4.5661800227323495
# Distance to train[73]: 3.9887341350358256
# Distance to train[74]: 1.489966442575134
# Distance to train[75]: 4.180908992073374
# Distance to train[76]: 2.62678510731274
# Distance to train[77]: 2.4839484696748437
# Distance to train[78]: 2.6944387170614967
# Distance to train[79]: 1.5459624833740306
# Distance to train[80]: 4.505552130427523
# Distance to train[81]: 0.7280109889280518
# Distance to train[82]: 4.635730794599703
# Distance to train[83]: 2.5159491250818253
# Distance to train[84]: 4.342810150121693
# Distance to train[85]: 4.296510211788167
# Distance to train[86]: 1.9519221295943139
# Distance to train[87]: 4.40681290730614
# Distance to train[88]: 0.9273618495495703
# Distance to train[89]: 1.489966442575134
# Distance to train[90]: 1.6999999999999997
# Distance to train[91]: 2.1377558326431947
# Distance to train[92]: 0.7549834435270756
# Distance to train[93]: 0.9327379053088819
# Distance to train[94]: 1.0908712114635712
# Distance to train[95]: 1.1618950038622253
# Distance to train[96]: 4.215447781671598
# Distance to train[97]: 2.042057785666213
# Distance to train[98]: 1.072380529476361
# Distance to train[99]: 0.5099019513592784
# Distance to train[100]: 4.318564576337836
# Distance to train[101]: 1.452583904633395
# Distance to train[102]: 1.5132745950421553
# Distance to train[103]: 0.7874007874011811
# Distance to train[104]: 1.483239697419132
# Distance to train[105]: 4.456455991031437
# Distance to train[106]: 4.273172123844299
# Distance to train[107]: 4.376071297408212
# Distance to train[108]: 0.9327379053088813
# Distance to train[109]: 1.7233687939614086
# Distance to train[110]: 2.685144316419511
# Distance to train[111]: 4.486646854834911
# K-nearest: [(24, 0.5099019513592784), (99, 0.5099019513592784), (56, 0.5196152422706629)]
# Nearest Labels: [np.int64(2), np.int64(2), np.int64(2)]
# Counts: [0 0 3]
# Distance to train[0]: 0.9695359714832656
# Distance to train[1]: 0.48989794855663554
# Distance to train[2]: 2.177154105707724
# Distance to train[3]: 3.258834147360065
# Distance to train[4]: 2.1260291625469296
# Distance to train[5]: 2.9342801502242417
# Distance to train[6]: 3.0822070014844885
# Distance to train[7]: 1.1357816691600546
# Distance to train[8]: 1.944222209522358
# Distance to train[9]: 2.615339366124404
# Distance to train[10]: 1.118033988749895
# Distance to train[11]: 2.1118712081942874
# Distance to train[12]: 0.5196152422706634
# Distance to train[13]: 3.10322412983658
# Distance to train[14]: 1.4662878298615178
# Distance to train[15]: 0.58309518948453
# Distance to train[16]: 1.3379088160259653
# Distance to train[17]: 1.3820274961085248
# Distance to train[18]: 1.4282856857085695
# Distance to train[19]: 1.4106735979665883
# Distance to train[20]: 1.6278820596099708
# Distance to train[21]: 1.824828759089466
# Distance to train[22]: 1.431782106327635
# Distance to train[23]: 2.9410882339705484
# Distance to train[24]: 1.519868415357066
# Distance to train[25]: 0.7348469228349537
# Distance to train[26]: 0.9486832980505138
# Distance to train[27]: 0.6557438524302001
# Distance to train[28]: 1.0816653826391964
# Distance to train[29]: 2.6608269391300143
# Distance to train[30]: 3.1032241298365806
# Distance to train[31]: 3.570714214271425
# Distance to train[32]: 1.7058722109231979
# Distance to train[33]: 0.8999999999999998
# Distance to train[34]: 2.7802877548915683
# Distance to train[35]: 3.397057550292606
# Distance to train[36]: 1.6370705543744903
# Distance to train[37]: 3.1080540535840107
# Distance to train[38]: 1.5811388300841893
# Distance to train[39]: 1.3820274961085255
# Distance to train[40]: 3.263433774416144
# Distance to train[41]: 0.7348469228349535
# Distance to train[42]: 3.171750305430741
# Distance to train[43]: 0.8426149773176358
# Distance to train[44]: 3.1064449134018135
# Distance to train[45]: 2.582634314028992
# Distance to train[46]: 2.527844931952908
# Distance to train[47]: 2.360084744241189
# Distance to train[48]: 2.0712315177207974
# Distance to train[49]: 3.1256999216175565
# Distance to train[50]: 3.046309242345563
# Distance to train[51]: 1.8601075237738272
# Distance to train[52]: 2.4083189157584592
# Distance to train[53]: 3.168595903550972
# Distance to train[54]: 2.264950330581225
# Distance to train[55]: 3.0413812651491092
# Distance to train[56]: 1.4764823060233399
# Distance to train[57]: 2.1886068628239297
# Distance to train[58]: 3.389690251335659
# Distance to train[59]: 3.2186953878862163
# Distance to train[60]: 2.383275057562597
# Distance to train[61]: 3.122498999199199
# Distance to train[62]: 3.336165463522455
# Distance to train[63]: 2.983286778035259
# Distance to train[64]: 0.5916079783099616
# Distance to train[65]: 2.6343879744638983
# Distance to train[66]: 3.34215499341368
# Distance to train[67]: 3.146426544510455
# Distance to train[68]: 2.98496231131986
# Distance to train[69]: 3.0789608636681307
# Distance to train[70]: 0.8888194417315586
# Distance to train[71]: 1.1489125293076055
# Distance to train[72]: 3.2372828112477294
# Distance to train[73]: 2.749545416973504
# Distance to train[74]: 0.9110433579144298
# Distance to train[75]: 2.9
# Distance to train[76]: 3.626292872893749
# Distance to train[77]: 1.3190905958272916
# Distance to train[78]: 3.5958309192730407
# Distance to train[79]: 1.2727922061357857
# Distance to train[80]: 3.363034344160047
# Distance to train[81]: 1.3856406460551016
# Distance to train[82]: 3.429285639896449
# Distance to train[83]: 3.3970575502926064
# Distance to train[84]: 3.179622619116929
# Distance to train[85]: 3.014962686336267
# Distance to train[86]: 2.745906043549196
# Distance to train[87]: 3.1
# Distance to train[88]: 2.459674775249768
# Distance to train[89]: 0.7416198487095659
# Distance to train[90]: 0.5830951894845301
# Distance to train[91]: 0.7071067811865474
# Distance to train[92]: 2.1307275752662513
# Distance to train[93]: 2.0639767440550294
# Distance to train[94]: 1.1135528725660047
# Distance to train[95]: 1.6186414056238645
# Distance to train[96]: 2.8354893757515653
# Distance to train[97]: 0.6164414002968974
# Distance to train[98]: 2.4124676163629637
# Distance to train[99]: 1.519868415357066
# Distance to train[100]: 3.023243291566195
# Distance to train[101]: 1.1401754250991376
# Distance to train[102]: 0.9486832980505138
# Distance to train[103]: 1.5132745950421556
# Distance to train[104]: 0.5916079783099617
# Distance to train[105]: 3.141655614481002
# Distance to train[106]: 3.1096623610932426
# Distance to train[107]: 3.0133038346638723
# Distance to train[108]: 1.9442222095223576
# Distance to train[109]: 0.5477225575051662
# Distance to train[110]: 3.7656340767525465
# Distance to train[111]: 3.2186953878862163
# K-nearest: [(1, 0.48989794855663554), (12, 0.5196152422706634), (109, 0.5477225575051662)]
# Nearest Labels: [np.int64(1), np.int64(1), np.int64(1)]
# Counts: [0 3]
# Distance to train[0]: 3.336165463522456
# Distance to train[1]: 3.2264531609803355
# Distance to train[2]: 4.852834223420371
# Distance to train[3]: 1.284523257866513
# Distance to train[4]: 4.611941023040082
# Distance to train[5]: 0.9695359714832659
# Distance to train[6]: 0.5196152422706631
# Distance to train[7]: 3.184336665618132
# Distance to train[8]: 4.670117771534247
# Distance to train[9]: 5.101960407529639
# Distance to train[10]: 4.347413023856832
# Distance to train[11]: 5.123475382979799
# Distance to train[12]: 3.1559467676119004
# Distance to train[13]: 5.725382083319855
# Distance to train[14]: 3.7815340802378077
# Distance to train[15]: 3.132091952673165
# Distance to train[16]: 4.207136793592526
# Distance to train[17]: 4.240283009422838
# Distance to train[18]: 3.8871583451153624
# Distance to train[19]: 4.402272140611028
# Distance to train[20]: 3.9471508711981107
# Distance to train[21]: 4.485532298401162
# Distance to train[22]: 3.5298725189445586
# Distance to train[23]: 1.319090595827292
# Distance to train[24]: 4.349712634186309
# Distance to train[25]: 3.3630343441600474
# Distance to train[26]: 2.783882181415011
# Distance to train[27]: 3.2954514106568165
# Distance to train[28]: 3.671511950137164
# Distance to train[29]: 5.25452186216786
# Distance to train[30]: 0.5477225575051662
# Distance to train[31]: 1.7262676501632073
# Distance to train[32]: 4.6
# Distance to train[33]: 3.2124756808418025
# Distance to train[34]: 0.860232526704263
# Distance to train[35]: 0.3605551275463992
# Distance to train[36]: 4.136423575989287
# Distance to train[37]: 1.424780684877501
# Distance to train[38]: 4.224926034855522
# Distance to train[39]: 2.5337718918639855
# Distance to train[40]: 1.2083045973594577
# Distance to train[41]: 3.9736632972611052
# Distance to train[42]: 5.534437640808684
# Distance to train[43]: 3.2832910318764013
# Distance to train[44]: 1.3928388277184123
# Distance to train[45]: 5.27825728815866
# Distance to train[46]: 5.085272854036448
# Distance to train[47]: 5.079370039680118
# Distance to train[48]: 4.9010203019371374
# Distance to train[49]: 0.6000000000000005
# Distance to train[50]: 1.081665382639197
# Distance to train[51]: 4.350861983561418
# Distance to train[52]: 4.934571916590132
# Distance to train[53]: 2.1517434791350016
# Distance to train[54]: 4.641120554348917
# Distance to train[55]: 1.3416407864998738
# Distance to train[56]: 4.373785545725808
# Distance to train[57]: 4.77283982551269
# Distance to train[58]: 1.4899664425751336
# Distance to train[59]: 0.7810249675906655
# Distance to train[60]: 5.064582904840241
# Distance to train[61]: 0.8124038404635964
# Distance to train[62]: 1.630950643030009
# Distance to train[63]: 0.479583152331272
# Distance to train[64]: 3.402939905434711
# Distance to train[65]: 5.229722745997153
# Distance to train[66]: 6.041522986797286
# Distance to train[67]: 0.8062257748298552
# Distance to train[68]: 1.2569805089976533
# Distance to train[69]: 0.8544003745317533
# Distance to train[70]: 3.5805027579936315
# Distance to train[71]: 3.6180105030251086
# Distance to train[72]: 1.1357816691600546
# Distance to train[73]: 1.0723805294763613
# Distance to train[74]: 3.481379037105842
# Distance to train[75]: 0.8366600265340757
# Distance to train[76]: 6.485368146836385
# Distance to train[77]: 2.80178514522438
# Distance to train[78]: 5.844655678480983
# Distance to train[79]: 3.6180105030251095
# Distance to train[80]: 0.3464101615137755
# Distance to train[81]: 3.976179070414209
# Distance to train[82]: 0.412310562561766
# Distance to train[83]: 6.174949392505174
# Distance to train[84]: 0.5830951894845305
# Distance to train[85]: 1.296148139681572
# Distance to train[86]: 5.527205442174191
# Distance to train[87]: 1.0295630140987002
# Distance to train[88]: 4.874423042781575
# Distance to train[89]: 3.24037034920393
# Distance to train[90]: 3.0967725134404045
# Distance to train[91]: 2.7658633371878665
# Distance to train[92]: 4.629254799641083
# Distance to train[93]: 4.661544808322666
# Distance to train[94]: 4.179712908801274
# Distance to train[95]: 4.253234063627348
# Distance to train[96]: 1.315294643796591
# Distance to train[97]: 3.028200785945345
# Distance to train[98]: 5.012983143797712
# Distance to train[99]: 4.349712634186309
# Distance to train[100]: 0.9000000000000004
# Distance to train[101]: 3.788139384975162
# Distance to train[102]: 3.1543620591175006
# Distance to train[103]: 3.9089640571384123
# Distance to train[104]: 3.802630668366309
# Distance to train[105]: 0.7071067811865478
# Distance to train[106]: 0.678232998312527
# Distance to train[107]: 1.2609520212918492
# Distance to train[108]: 4.746577714522327
# Distance to train[109]: 3.204684071792413
# Distance to train[110]: 6.090155991434047
# Distance to train[111]: 1.3453624047073711
# K-nearest: [(80, 0.3464101615137755), (35, 0.3605551275463992), (82, 0.412310562561766)]
# Nearest Labels: [np.int64(0), np.int64(0), np.int64(0)]
# Counts: [3]
# Distance to train[0]: 2.5436194683953803
# Distance to train[1]: 2.826658805020514
# Distance to train[2]: 0.9949874371066199
# Distance to train[3]: 5.866003750424986
# Distance to train[4]: 1.3747727084867518
# Distance to train[5]: 5.401851534427801
# Distance to train[6]: 5.463515351859095
# Distance to train[7]: 3.8183766184073566
# Distance to train[8]: 1.1357816691600544
# Distance to train[9]: 1.170469991071962
# Distance to train[10]: 1.9899748742132395
# Distance to train[11]: 0.877496438739212
# Distance to train[12]: 3.0495901363953815
# Distance to train[13]: 0.6782329983125268
# Distance to train[14]: 1.9390719429665313
# Distance to train[15]: 3.198437118343895
# Distance to train[16]: 1.7320508075688765
# Distance to train[17]: 1.593737745050923
# Distance to train[18]: 3.0282007859453435
# Distance to train[19]: 1.6911534525287764
# Distance to train[20]: 1.7029386365926398
# Distance to train[21]: 1.3784048752090217
# Distance to train[22]: 2.284731931759172
# Distance to train[23]: 5.562373594069351
# Distance to train[24]: 1.9339079605813718
# Distance to train[25]: 2.7549954627911823
# Distance to train[26]: 3.2295510523910282
# Distance to train[27]: 2.9899832775452104
# Distance to train[28]: 2.1213203435596424
# Distance to train[29]: 0.43588989435406733
# Distance to train[30]: 5.499090833947007
# Distance to train[31]: 6.240192304729077
# Distance to train[32]: 1.3638181696985852
# Distance to train[33]: 2.709243436828813
# Distance to train[34]: 5.251666402200352
# Distance to train[35]: 5.459853477887479
# Distance to train[36]: 1.4999999999999993
# Distance to train[37]: 5.738466694161429
# Distance to train[38]: 1.8466185312619385
# Distance to train[39]: 4.047221268969612
# Distance to train[40]: 5.813776741499454
# Distance to train[41]: 2.24276614920058
# Distance to train[42]: 1.014889156509222
# Distance to train[43]: 2.68700576850888
# Distance to train[44]: 5.758472019555188
# Distance to train[45]: 0.5477225575051659
# Distance to train[46]: 0.9273618495495699
# Distance to train[47]: 1.0295630140987
# Distance to train[48]: 1.183215956619923
# Distance to train[49]: 5.504543577809154
# Distance to train[50]: 5.581218504950329
# Distance to train[51]: 1.4866068747318506
# Distance to train[52]: 0.9848857801796099
# Distance to train[53]: 5.953990258641678
# Distance to train[54]: 1.587450786638754
# Distance to train[55]: 5.686826883245173
# Distance to train[56]: 2.1095023109728985
# Distance to train[57]: 1.048808848170151
# Distance to train[58]: 6.004997918400972
# Distance to train[59]: 5.68770604022395
# Distance to train[60]: 0.5567764362830021
# Distance to train[61]: 5.608921464952064
# Distance to train[62]: 5.998333101787528
# Distance to train[63]: 5.2659282182726335
# Distance to train[64]: 3.023243291566194
# Distance to train[65]: 0.8660254037844384
# Distance to train[66]: 0.529150262212918
# Distance to train[67]: 5.636488268416781
# Distance to train[68]: 5.60357029044876
# Distance to train[69]: 5.588380803059148
# Distance to train[70]: 2.461706725018234
# Distance to train[71]: 2.066397831977182
# Distance to train[72]: 5.826662852782886
# Distance to train[73]: 5.277309920783504
# Distance to train[74]: 2.2494443758403984
# Distance to train[75]: 5.372150407425316
# Distance to train[76]: 0.9273618495495708
# Distance to train[77]: 3.956008088970496
# Distance to train[78]: 1.1045361017187263
# Distance to train[79]: 2.042057785666213
# Distance to train[80]: 5.637375275782161
# Distance to train[81]: 1.9874606914351791
# Distance to train[82]: 5.659505278732408
# Distance to train[83]: 0.6082762530298225
# Distance to train[84]: 5.562373594069352
# Distance to train[85]: 5.612486080160911
# Distance to train[86]: 0.2645751311064594
# Distance to train[87]: 5.658621740318043
# Distance to train[88]: 1.449137674618944
# Distance to train[89]: 2.7676705006196096
# Distance to train[90]: 2.9
# Distance to train[91]: 3.3361654635224554
# Distance to train[92]: 1.4662878298615176
# Distance to train[93]: 1.3527749258468678
# Distance to train[94]: 1.7916472867168913
# Distance to train[95]: 1.4387494569938155
# Distance to train[96]: 5.47265931700485
# Distance to train[97]: 3.2999999999999994
# Distance to train[98]: 1.1180339887498947
# Distance to train[99]: 1.9339079605813718
# Distance to train[100]: 5.539855593785816
# Distance to train[101]: 1.9052558883257653
# Distance to train[102]: 2.8266588050205144
# Distance to train[103]: 2.073644135332772
# Distance to train[104]: 2.284731931759172
# Distance to train[105]: 5.582114294781145
# Distance to train[106]: 5.520869496736904
# Distance to train[107]: 5.632938842203065
# Distance to train[108]: 1.2206555615733703
# Distance to train[109]: 2.787471972953271
# Distance to train[110]: 1.1357816691600549
# Distance to train[111]: 5.826662852782886
# K-nearest: [(86, 0.2645751311064594), (29, 0.43588989435406733), (66, 0.529150262212918)]
# Nearest Labels: [np.int64(2), np.int64(2), np.int64(2)]
# Counts: [0 0 3]
# Distance to train[0]: 3.154362059117501
# Distance to train[1]: 2.920616373302046
# Distance to train[2]: 4.796873982084582
# Distance to train[3]: 0.4123105625617658
# Distance to train[4]: 4.590206967011399
# Distance to train[5]: 0.4242640687119285
# Distance to train[6]: 0.5000000000000004
# Distance to train[7]: 2.569046515733026
# Distance to train[8]: 4.5793012567421245
# Distance to train[9]: 5.0823223038292245
# Distance to train[10]: 4.047221268969612
# Distance to train[11]: 4.9749371855331
# Distance to train[12]: 2.7820855486487113
# Distance to train[13]: 5.746303159423456
# Distance to train[14]: 3.7282703764614498
# Distance to train[15]: 2.711088342345192
# Distance to train[16]: 4.037325847637271
# Distance to train[17]: 4.08656334834051
# Distance to train[18]: 3.4741905532080417
# Distance to train[19]: 4.2
# Distance to train[20]: 3.964845520319802
# Distance to train[21]: 4.397726685459204
# Distance to train[22]: 3.4583232931581165
# Distance to train[23]: 0.3741657386773941
# Distance to train[24]: 4.120679555607302
# Distance to train[25]: 3.0577769702841313
# Distance to train[26]: 2.4959967948697366
# Distance to train[27]: 2.9189039038652846
# Distance to train[28]: 3.524202037341219
# Distance to train[29]: 5.262128846769148
# Distance to train[30]: 0.42426406871192857
# Distance to train[31]: 0.9055385138137417
# Distance to train[32]: 4.447471191587417
# Distance to train[33]: 2.989983277545211
# Distance to train[34]: 0.44721359549995826
# Distance to train[35]: 1.2369316876852985
# Distance to train[36]: 4.11703777004778
# Distance to train[37]: 0.5000000000000002
# Distance to train[38]: 4.060788100849391
# Distance to train[39]: 1.969771560359221
# Distance to train[40]: 0.42426406871192884
# Distance to train[41]: 3.6837480912787726
# Distance to train[42]: 5.597320787662611
# Distance to train[43]: 3.0397368307141326
# Distance to train[44]: 0.469041575982343
# Distance to train[45]: 5.24785670536077
# Distance to train[46]: 5.06951674225463
# Distance to train[47]: 4.9899899799498595
# Distance to train[48]: 4.768647607026546
# Distance to train[49]: 0.4242640687119284
# Distance to train[50]: 0.22360679774997919
# Distance to train[51]: 4.300000000000001
# Distance to train[52]: 4.914264950122246
# Distance to train[53]: 1.2288205727444508
# Distance to train[54]: 4.589117562233507
# Distance to train[55]: 0.4242640687119284
# Distance to train[56]: 4.097560249709575
# Distance to train[57]: 4.7455242070818695
# Distance to train[58]: 0.6633249580710795
# Distance to train[59]: 0.22360679774997919
# Distance to train[60]: 5.044799302251776
# Distance to train[61]: 0.1999999999999999
# Distance to train[62]: 0.7483314773547879
# Distance to train[63]: 0.7000000000000002
# Distance to train[64]: 2.986636904613616
# Distance to train[65]: 5.200961449578338
# Distance to train[66]: 6.044832503882965
# Distance to train[67]: 0.17320508075688762
# Distance to train[68]: 0.3162277660168376
# Distance to train[69]: 0.22360679774997919
# Distance to train[70]: 3.3256578296631782
# Distance to train[71]: 3.5454195802471675
# Distance to train[72]: 0.3605551275463988
# Distance to train[73]: 0.3872983346207416
# Distance to train[74]: 3.3555923471125033
# Distance to train[75]: 0.44721359549995826
# Distance to train[76]: 6.442049363362563
# Distance to train[77]: 2.211334438749598
# Distance to train[78]: 5.984981202978001
# Distance to train[79]: 3.581898937714463
# Distance to train[80]: 0.7348469228349532
# Distance to train[81]: 3.8223029707232783
# Distance to train[82]: 1.044030650891055
# Distance to train[83]: 6.158733636065129
# Distance to train[84]: 0.4242640687119283
# Distance to train[85]: 0.3741657386773939
# Distance to train[86]: 5.492722457943783
# Distance to train[87]: 0.14142135623730964
# Distance to train[88]: 4.831148931672464
# Distance to train[89]: 2.969848480983499
# Distance to train[90]: 2.808914381037628
# Distance to train[91]: 2.4020824298928627
# Distance to train[92]: 4.5661800227323495
# Distance to train[93]: 4.598912915026768
# Distance to train[94]: 3.968626966596886
# Distance to train[95]: 4.189272013130683
# Distance to train[96]: 0.41231056256176596
# Distance to train[97]: 2.5942243542145693
# Distance to train[98]: 4.962862077471023
# Distance to train[99]: 4.120679555607302
# Distance to train[100]: 0.09999999999999964
# Distance to train[101]: 3.691882988394946
# Distance to train[102]: 2.913760456866693
# Distance to train[103]: 3.7815340802378077
# Distance to train[104]: 3.538361202590827
# Distance to train[105]: 0.5477225575051661
# Distance to train[106]: 0.3741657386773942
# Distance to train[107]: 0.3316624790355397
# Distance to train[108]: 4.616275555033516
# Distance to train[109]: 2.9206163733020465
# Distance to train[110]: 6.20403094769844
# Distance to train[111]: 0.4582575694955842
# K-nearest: [(100, 0.09999999999999964), (87, 0.14142135623730964), (67, 0.17320508075688762)]
# Nearest Labels: [np.int64(0), np.int64(0), np.int64(0)]
# Counts: [3]
# Distance to train[0]: 2.118962010041709
# Distance to train[1]: 2.535744466621193
# Distance to train[2]: 0.8660254037844385
# Distance to train[3]: 5.472659317004851
# Distance to train[4]: 1.1180339887498956
# Distance to train[5]: 4.969909455915672
# Distance to train[6]: 5.148786264742401
# Distance to train[7]: 3.446737587922817
# Distance to train[8]: 0.9327379053088815
# Distance to train[9]: 0.5000000000000002
# Distance to train[10]: 1.8165902124584947
# Distance to train[11]: 1.1532562594670797
# Distance to train[12]: 2.7386127875258306
# Distance to train[13]: 1.4491376746189442
# Distance to train[14]: 1.5811388300841895
# Distance to train[15]: 2.8722813232690143
# Distance to train[16]: 1.435270009440732
# Distance to train[17]: 1.4352700094407325
# Distance to train[18]: 2.343074902771996
# Distance to train[19]: 1.414213562373095
# Distance to train[20]: 1.8439088914585775
# Distance to train[21]: 1.0099504938362076
# Distance to train[22]: 1.7776388834631178
# Distance to train[23]: 5.1903757089443925
# Distance to train[24]: 1.3341664064126335
# Distance to train[25]: 2.3515952032609695
# Distance to train[26]: 2.80178514522438
# Distance to train[27]: 2.592296279363144
# Distance to train[28]: 1.8165902124584952
# Distance to train[29]: 1.14455231422596
# Distance to train[30]: 5.167204273105525
# Distance to train[31]: 5.818934610390462
# Distance to train[32]: 1.104536101718726
# Distance to train[33]: 2.31948270094864
# Distance to train[34]: 4.959838707054898
# Distance to train[35]: 5.121523210920751
# Distance to train[36]: 1.615549442140351
# Distance to train[37]: 5.33572862878164
# Distance to train[38]: 1.2449899597988734
# Distance to train[39]: 3.6110940170535577
# Distance to train[40]: 5.375872022286244
# Distance to train[41]: 2.114237451186597
# Distance to train[42]: 0.953939201416946
# Distance to train[43]: 2.2803508501982757
# Distance to train[44]: 5.409251334519407
# Distance to train[45]: 0.9486832980505137
# Distance to train[46]: 0.7071067811865479
# Distance to train[47]: 0.5099019513592784
# Distance to train[48]: 0.7615773105863911
# Distance to train[49]: 5.132250968142537
# Distance to train[50]: 5.187484939737175
# Distance to train[51]: 1.0535653752852743
# Distance to train[52]: 0.640312423743285
# Distance to train[53]: 5.5830099408831435
# Distance to train[54]: 0.6480740698407857
# Distance to train[55]: 5.338539126015656
# Distance to train[56]: 1.4999999999999998
# Distance to train[57]: 0.9591663046625439
# Distance to train[58]: 5.5677643628300215
# Distance to train[59]: 5.313191131514092
# Distance to train[60]: 1.3228756555322956
# Distance to train[61]: 5.242136968832463
# Distance to train[62]: 5.574943945906542
# Distance to train[63]: 4.906118628814432
# Distance to train[64]: 2.660826939130014
# Distance to train[65]: 0.5567764362830022
# Distance to train[66]: 1.5165750888103098
# Distance to train[67]: 5.2848841046895245
# Distance to train[68]: 5.247856705360769
# Distance to train[69]: 5.260228131934963
# Distance to train[70]: 2.073644135332772
# Distance to train[71]: 1.9874606914351787
# Distance to train[72]: 5.4799635035281025
# Distance to train[73]: 4.8918299234540035
# Distance to train[74]: 2.1213203435596424
# Distance to train[75]: 5.0477717856495845
# Distance to train[76]: 1.8165902124584952
# Distance to train[77]: 3.5085609585697664
# Distance to train[78]: 1.7944358444926367
# Distance to train[79]: 1.9924858845171272
# Distance to train[80]: 5.27825728815866
# Distance to train[81]: 1.452583904633395
# Distance to train[82]: 5.391660226683428
# Distance to train[83]: 1.717556403731767
# Distance to train[84]: 5.174939613174245
# Distance to train[85]: 5.217278984298233
# Distance to train[86]: 1.3527749258468689
# Distance to train[87]: 5.304714883949937
# Distance to train[88]: 0.42426406871192884
# Distance to train[89]: 2.379075450674064
# Distance to train[90]: 2.5903667693977237
# Distance to train[91]: 3.057776970284131
# Distance to train[92]: 0.7416198487095665
# Distance to train[93]: 0.9643650760992954
# Distance to train[94]: 1.6881943016134127
# Distance to train[95]: 1.374772708486752
# Distance to train[96]: 5.141011573610781
# Distance to train[97]: 2.9983328701129897
# Distance to train[98]: 0.6082762530298224
# Distance to train[99]: 1.3341664064126335
# Distance to train[100]: 5.195190083144215
# Distance to train[101]: 1.91049731745428
# Distance to train[102]: 2.3727621035409348
# Distance to train[103]: 1.449137674618944
# Distance to train[104]: 2.2360679774997894
# Distance to train[105]: 5.297169055259611
# Distance to train[106]: 5.124451190127583
# Distance to train[107]: 5.292447448959697
# Distance to train[108]: 0.9
# Distance to train[109]: 2.5436194683953812
# Distance to train[110]: 1.670329308849007
# Distance to train[111]: 5.417564028232614
# K-nearest: [(88, 0.42426406871192884), (9, 0.5000000000000002), (47, 0.5099019513592784)]
# Nearest Labels: [np.int64(2), np.int64(2), np.int64(2)]
# Counts: [0 0 3]
# Distance to train[0]: 3.3030289129827497
# Distance to train[1]: 3.0903074280724887
# Distance to train[2]: 4.936598018878993
# Distance to train[3]: 0.4358898943540671
# Distance to train[4]: 4.712748667179272
# Distance to train[5]: 0.42426406871192857
# Distance to train[6]: 0.5000000000000003
# Distance to train[7]: 2.7531799795872414
# Distance to train[8]: 4.731807265728392
# Distance to train[9]: 5.208646657242168
# Distance to train[10]: 4.221374183841086
# Distance to train[11]: 5.137119815616529
# Distance to train[12]: 2.959729717389748
# Distance to train[13]: 5.880476171195663
# Distance to train[14]: 3.870400496072726
# Distance to train[15]: 2.8896366553599777
# Distance to train[16]: 4.1880783182743855
# Distance to train[17]: 4.249705872175156
# Distance to train[18]: 3.6345563690772495
# Distance to train[19]: 4.352011029397788
# Distance to train[20]: 4.106093033529563
# Distance to train[21]: 4.538722287164088
# Distance to train[22]: 3.59722114972099
# Distance to train[23]: 0.5477225575051661
# Distance to train[24]: 4.27551166528639
# Distance to train[25]: 3.226453160980336
# Distance to train[26]: 2.6476404589747453
# Distance to train[27]: 3.0886890422961
# Distance to train[28]: 3.682390527904394
# Distance to train[29]: 5.410175597889592
# Distance to train[30]: 0.4242640687119284
# Distance to train[31]: 0.9055385138137417
# Distance to train[32]: 4.6
# Distance to train[33]: 3.1559467676119
# Distance to train[34]: 0.5830951894845302
# Distance to train[35]: 1.1618950038622256
# Distance to train[36]: 4.262628297189424
# Distance to train[37]: 0.6082762530298221
# Distance to train[38]: 4.2130748865881795
# Distance to train[39]: 2.130727575266252
# Distance to train[40]: 0.42426406871192884
# Distance to train[41]: 3.8483762809787714
# Distance to train[42]: 5.721013896155122
# Distance to train[43]: 3.203123475609394
# Distance to train[44]: 0.5830951894845301
# Distance to train[45]: 5.390732788777423
# Distance to train[46]: 5.201922721455982
# Distance to train[47]: 5.134199061197375
# Distance to train[48]: 4.917316341257698
# Distance to train[49]: 0.4472135954999578
# Distance to train[50]: 0.3872983346207418
# Distance to train[51]: 4.435087372307337
# Distance to train[52]: 5.052722038663912
# Distance to train[53]: 1.3
# Distance to train[54]: 4.71805044483418
# Distance to train[55]: 0.529150262212918
# Distance to train[56]: 4.250882261366457
# Distance to train[57]: 4.880573736764972
# Distance to train[58]: 0.6782329983125265
# Distance to train[59]: 0.1732050807568877
# Distance to train[60]: 5.199038372622383
# Distance to train[61]: 0.14142135623730914
# Distance to train[62]: 0.7874007874011809
# Distance to train[63]: 0.7000000000000001
# Distance to train[64]: 3.159113799786263
# Distance to train[65]: 5.3376024580330075
# Distance to train[66]: 6.191930232165087
# Distance to train[67]: 0.17320508075688743
# Distance to train[68]: 0.4690415759823428
# Distance to train[69]: 0.2645751311064592
# Distance to train[70]: 3.4957116585897072
# Distance to train[71]: 3.6918829883949464
# Distance to train[72]: 0.3316624790355398
# Distance to train[73]: 0.4999999999999999
# Distance to train[74]: 3.5099857549568485
# Distance to train[75]: 0.4690415759823433
# Distance to train[76]: 6.592419889539805
# Distance to train[77]: 2.389560629069704
# Distance to train[78]: 6.1155539405682635
# Distance to train[79]: 3.7242448899072147
# Distance to train[80]: 0.6928203230275506
# Distance to train[81]: 3.968626966596886
# Distance to train[82]: 0.9539392014169455
# Distance to train[83]: 6.311101330195863
# Distance to train[84]: 0.3741657386773939
# Distance to train[85]: 0.5291502622129179
# Distance to train[86]: 5.643580423808985
# Distance to train[87]: 0.2449489742783179
# Distance to train[88]: 4.959838707054898
# Distance to train[89]: 3.1336879231984796
# Distance to train[90]: 2.9748949561287024
# Distance to train[91]: 2.574878637916747
# Distance to train[92]: 4.695742752749559
# Distance to train[93]: 4.727578661429126
# Distance to train[94]: 4.134005321718878
# Distance to train[95]: 4.334743360338649
# Distance to train[96]: 0.5916079783099616
# Distance to train[97]: 2.7766886753829647
# Distance to train[98]: 5.094114250780011
# Distance to train[99]: 4.27551166528639
# Distance to train[100]: 0.2645751311064589
# Distance to train[101]: 3.848376280978771
# Distance to train[102]: 3.074085229787879
# Distance to train[103]: 3.9242833740697165
# Distance to train[104]: 3.706750598570128
# Distance to train[105]: 0.5099019513592785
# Distance to train[106]: 0.31622776601683794
# Distance to train[107]: 0.4999999999999999
# Distance to train[108]: 4.773887304912003
# Distance to train[109]: 3.1
# Distance to train[110]: 6.336402764976356
# Distance to train[111]: 0.5196152422706634
# K-nearest: [(61, 0.14142135623730914), (67, 0.17320508075688743), (59, 0.1732050807568877)]
# Nearest Labels: [np.int64(0), np.int64(0), np.int64(0)]
# Counts: [3]
# Distance to train[0]: 0.9486832980505137
# Distance to train[1]: 1.2806248474865702
# Distance to train[2]: 1.0099504938362076
# Distance to train[3]: 4.154515615568197
# Distance to train[4]: 0.9165151389911675
# Distance to train[5]: 3.670149860700514
# Distance to train[6]: 3.738983819167984
# Distance to train[7]: 2.406241883103193
# Distance to train[8]: 0.8831760866327846
# Distance to train[9]: 1.42828568570857
# Distance to train[10]: 1.1789826122551597
# Distance to train[11]: 1.2884098726725122
# Distance to train[12]: 1.5394804318340658
# Distance to train[13]: 1.8999999999999997
# Distance to train[14]: 0.4582575694955842
# Distance to train[15]: 1.7029386365926407
# Distance to train[16]: 0.6708203932499371
# Distance to train[17]: 0.6403124237432849
# Distance to train[18]: 1.9183326093250876
# Distance to train[19]: 0.8774964387392123
# Distance to train[20]: 0.3316624790355398
# Distance to train[21]: 0.7416198487095663
# Distance to train[22]: 0.7937253933193774
# Distance to train[23]: 3.861346915261565
# Distance to train[24]: 1.1357816691600546
# Distance to train[25]: 1.2884098726725128
# Distance to train[26]: 1.5811388300841902
# Distance to train[27]: 1.5264337522473752
# Distance to train[28]: 0.6244997998398405
# Distance to train[29]: 1.42828568570857
# Distance to train[30]: 3.7749172176353754
# Distance to train[31]: 4.548626166217664
# Distance to train[32]: 0.8774964387392118
# Distance to train[33]: 1.161895003862225
# Distance to train[34]: 3.5312887166019147
# Distance to train[35]: 3.7603191353926335
# Distance to train[36]: 0.2828427124746193
# Distance to train[37]: 4.042276586281548
# Distance to train[38]: 0.9486832980505137
# Distance to train[39]: 2.443358344574124
# Distance to train[40]: 4.102438299353204
# Distance to train[41]: 1.0488088481701514
# Distance to train[42]: 1.860107523773827
# Distance to train[43]: 1.1532562594670797
# Distance to train[44]: 4.058324777540605
# Distance to train[45]: 1.4035668847618201
# Distance to train[46]: 1.2999999999999998
# Distance to train[47]: 1.322875655532295
# Distance to train[48]: 1.1618950038622247
# Distance to train[49]: 3.7881393849751626
# Distance to train[50]: 3.872983346207417
# Distance to train[51]: 0.6782329983125266
# Distance to train[52]: 1.1832159566199232
# Distance to train[53]: 4.298837052040936
# Distance to train[54]: 1.212435565298214
# Distance to train[55]: 3.9786932528155527
# Distance to train[56]: 1.3038404810405297
# Distance to train[57]: 0.9433981132056607
# Distance to train[58]: 4.3069710934716054
# Distance to train[59]: 3.964845520319802
# Distance to train[60]: 1.2165525060596436
# Distance to train[61]: 3.879432948254165
# Distance to train[62]: 4.3069710934716054
# Distance to train[63]: 3.541186241925155
# Distance to train[64]: 1.6155494421403516
# Distance to train[65]: 1.449137674618944
# Distance to train[66]: 2.1886068628239284
# Distance to train[67]: 3.9115214431215897
# Distance to train[68]: 3.8948684188300895
# Distance to train[69]: 3.8626415831655936
# Distance to train[70]: 1.0816653826391969
# Distance to train[71]: 0.3464101615137755
# Distance to train[72]: 4.1036569057366385
# Distance to train[73]: 3.54964786985977
# Distance to train[74]: 0.5744562646538031
# Distance to train[75]: 3.6373066958946425
# Distance to train[76]: 2.5942243542145693
# Distance to train[77]: 2.4372115213907883
# Distance to train[78]: 2.2516660498395407
# Distance to train[79]: 0.3162277660168378
# Distance to train[80]: 3.9306488014067096
# Distance to train[81]: 0.7745966692414835
# Distance to train[82]: 3.944616584663204
# Distance to train[83]: 2.3108440016582685
# Distance to train[84]: 3.8379682124790975
# Distance to train[85]: 3.9127995093027703
# Distance to train[86]: 1.6431676725154982
# Distance to train[87]: 3.9382737335030438
# Distance to train[88]: 1.3674794331177342
# Distance to train[89]: 1.2206555615733705
# Distance to train[90]: 1.3038404810405302
# Distance to train[91]: 1.7146428199482249
# Distance to train[92]: 1.0488088481701512
# Distance to train[93]: 0.9486832980505137
# Distance to train[94]: 0.7483314773547886
# Distance to train[95]: 0.374165738677394
# Distance to train[96]: 3.7682887362833544
# Distance to train[97]: 1.7832554500127011
# Distance to train[98]: 1.272792206135785
# Distance to train[99]: 1.1357816691600546
# Distance to train[100]: 3.818376618407357
# Distance to train[101]: 0.3162277660168384
# Distance to train[102]: 1.2727922061357861
# Distance to train[103]: 0.8660254037844385
# Distance to train[104]: 0.9643650760992958
# Distance to train[105]: 3.853569773599539
# Distance to train[106]: 3.7907782842049738
# Distance to train[107]: 3.9293765408777
# Distance to train[108]: 1.0488088481701514
# Distance to train[109]: 1.256980508997654
# Distance to train[110]: 2.445403852127497
# Distance to train[111]: 4.1231056256176615
# K-nearest: [(36, 0.2828427124746193), (79, 0.3162277660168378), (101, 0.3162277660168384)]
# Nearest Labels: [np.int64(1), np.int64(1), np.int64(1)]
# Counts: [0 3]
# Distance to train[0]: 1.1045361017187254
# Distance to train[1]: 1.3114877048604
# Distance to train[2]: 1.009950493836208
# Distance to train[3]: 4.273172123844299
# Distance to train[4]: 1.0
# Distance to train[5]: 3.822302970723278
# Distance to train[6]: 3.885871845545089
# Distance to train[7]: 2.3937418407171647
# Distance to train[8]: 0.8831760866327849
# Distance to train[9]: 1.5099668870541503
# Distance to train[10]: 1.0246950765959595
# Distance to train[11]: 1.1224972160321824
# Distance to train[12]: 1.5588457268119895
# Distance to train[13]: 1.8303005217723127
# Distance to train[14]: 0.7416198487095662
# Distance to train[15]: 1.7146428199482247
# Distance to train[16]: 0.6557438524302002
# Distance to train[17]: 0.5916079783099616
# Distance to train[18]: 1.9697715603592205
# Distance to train[19]: 0.7937253933193772
# Distance to train[20]: 0.4582575694955843
# Distance to train[21]: 0.8062257748298551
# Distance to train[22]: 1.0630145812734648
# Distance to train[23]: 3.971145930332956
# Distance to train[24]: 1.161895003862225
# Distance to train[25]: 1.3490737563232043
# Distance to train[26]: 1.70293863659264
# Distance to train[27]: 1.5588457268119895
# Distance to train[28]: 0.7549834435270751
# Distance to train[29]: 1.3856406460551023
# Distance to train[30]: 3.923009049186606
# Distance to train[31]: 4.6551047249229525
# Distance to train[32]: 0.8185352771872447
# Distance to train[33]: 1.2845232578665124
# Distance to train[34]: 3.6565010597564442
# Distance to train[35]: 3.957271787481876
# Distance to train[36]: 0.346410161513776
# Distance to train[37]: 4.154515615568197
# Distance to train[38]: 1.0488088481701512
# Distance to train[39]: 2.511971337416094
# Distance to train[40]: 4.2391036788453285
# Distance to train[41]: 0.9055385138137411
# Distance to train[42]: 1.9235384061671346
# Distance to train[43]: 1.2609520212918486
# Distance to train[44]: 4.1581245772583575
# Distance to train[45]: 1.3527749258468689
# Distance to train[46]: 1.3379088160259656
# Distance to train[47]: 1.3304134695650072
# Distance to train[48]: 1.1357816691600546
# Distance to train[49]: 3.945883931389772
# Distance to train[50]: 4.004996878900157
# Distance to train[51]: 0.8366600265340757
# Distance to train[52]: 1.24899959967968
# Distance to train[53]: 4.358898943540673
# Distance to train[54]: 1.374772708486752
# Distance to train[55]: 4.080441152620633
# Distance to train[56]: 1.3038404810405295
# Distance to train[57]: 0.974679434480897
# Distance to train[58]: 4.428317965096905
# Distance to train[59]: 4.1085277168348275
# Distance to train[60]: 1.1135528725660047
# Distance to train[61]: 4.018706259482024
# Distance to train[62]: 4.4147480109288235
# Distance to train[63]: 3.7121422386541165
# Distance to train[64]: 1.609347693943108
# Distance to train[65]: 1.4764823060233405
# Distance to train[66]: 2.1
# Distance to train[67]: 4.047221268969612
# Distance to train[68]: 4.00374824383352
# Distance to train[69]: 3.989987468652
# Distance to train[70]: 1.1445523142259593
# Distance to train[71]: 0.4898979485566354
# Distance to train[72]: 4.219004621945797
# Distance to train[73]: 3.6823905279043934
# Distance to train[74]: 0.6557438524301997
# Distance to train[75]: 3.769615364994152
# Distance to train[76]: 2.4637369989509845
# Distance to train[77]: 2.4859605789312105
# Distance to train[78]: 2.2649503305812257
# Distance to train[79]: 0.5099019513592781
# Distance to train[80]: 4.102438299353203
# Distance to train[81]: 0.9165151389911681
# Distance to train[82]: 4.103656905736638
# Distance to train[83]: 2.186321110907545
# Distance to train[84]: 3.9987498046264407
# Distance to train[85]: 4.031128874149275
# Distance to train[86]: 1.51657508881031
# Distance to train[87]: 4.060788100849391
# Distance to train[88]: 1.5
# Distance to train[89]: 1.3076696830622019
# Distance to train[90]: 1.3638181696985856
# Distance to train[91]: 1.7606816861659005
# Distance to train[92]: 1.1747340124470729
# Distance to train[93]: 1.0099504938362078
# Distance to train[94]: 0.6000000000000001
# Distance to train[95]: 0.4242640687119287
# Distance to train[96]: 3.8678159211627428
# Distance to train[97]: 1.7944358444926358
# Distance to train[98]: 1.3190905958272918
# Distance to train[99]: 1.161895003862225
# Distance to train[100]: 3.94715087119811
# Distance to train[101]: 0.31622776601683816
# Distance to train[102]: 1.4071247279470291
# Distance to train[103]: 1.0630145812734648
# Distance to train[104]: 0.8185352771872447
# Distance to train[105]: 3.9837168574084174
# Distance to train[106]: 3.948417404479927
# Distance to train[107]: 4.034848200366403
# Distance to train[108]: 1.0295630140987
# Distance to train[109]: 1.2884098726725126
# Distance to train[110]: 2.4617067250182347
# Distance to train[111]: 4.242640687119286
# K-nearest: [(101, 0.31622776601683816), (36, 0.346410161513776), (95, 0.4242640687119287)]
# Nearest Labels: [np.int64(1), np.int64(1), np.int64(1)]
# Counts: [0 3]
# Distance to train[0]: 0.3999999999999998
# Distance to train[1]: 0.3741657386773939
# Distance to train[2]: 1.849324200890693
# Distance to train[3]: 3.258834147360065
# Distance to train[4]: 1.7146428199482247
# Distance to train[5]: 2.819574435974337
# Distance to train[6]: 2.9597297173897488
# Distance to train[7]: 1.479864858694874
# Distance to train[8]: 1.6431676725154984
# Distance to train[9]: 2.222611077089287
# Distance to train[10]: 1.1874342087037917
# Distance to train[11]: 1.9849433241279204
# Distance to train[12]: 0.6244997998398397
# Distance to train[13]: 2.830194339616981
# Distance to train[14]: 0.9327379053088816
# Distance to train[15]: 0.7745966692414831
# Distance to train[16]: 1.0535653752852743
# Distance to train[17]: 1.1357816691600546
# Distance to train[18]: 1.3928388277184112
# Distance to train[19]: 1.2206555615733703
# Distance to train[20]: 1.2124355652982146
# Distance to train[21]: 1.4594519519326428
# Distance to train[22]: 0.8426149773176359
# Distance to train[23]: 2.9580398915498076
# Distance to train[24]: 1.292284798332008
# Distance to train[25]: 0.5477225575051662
# Distance to train[26]: 0.648074069840786
# Distance to train[27]: 0.6708203932499366
# Distance to train[28]: 0.6403124237432846
# Distance to train[29]: 2.3706539182259396
# Distance to train[30]: 2.98496231131986
# Distance to train[31]: 3.623534186398688
# Distance to train[32]: 1.466287829861518
# Distance to train[33]: 0.49999999999999967
# Distance to train[34]: 2.7110883423451915
# Distance to train[35]: 3.1272991542223783
# Distance to train[36]: 1.2569805089976542
# Distance to train[37]: 3.1304951684997055
# Distance to train[38]: 1.2409673645990853
# Distance to train[39]: 1.4594519519326423
# Distance to train[40]: 3.2202484376209237
# Distance to train[41]: 0.8124038404635958
# Distance to train[42]: 2.7748873851023217
# Distance to train[43]: 0.45825756949558366
# Distance to train[44]: 3.151190251317746
# Distance to train[45]: 2.3000000000000003
# Distance to train[46]: 2.1656407827707715
# Distance to train[47]: 2.0615528128088303
# Distance to train[48]: 1.8138357147217052
# Distance to train[49]: 2.9949958263743874
# Distance to train[50]: 3.003331483536241
# Distance to train[51]: 1.4212670403551895
# Distance to train[52]: 2.0346989949375813
# Distance to train[53]: 3.331666249791536
# Distance to train[54]: 1.824828759089466
# Distance to train[55]: 3.0740852297878796
# Distance to train[56]: 1.3190905958272918
# Distance to train[57]: 1.8248287590894667
# Distance to train[58]: 3.3985290935932855
# Distance to train[59]: 3.1336879231984796
# Distance to train[60]: 2.14009345590327
# Distance to train[61]: 3.04138126514911
# Distance to train[62]: 3.380828300875393
# Distance to train[63]: 2.792848008753788
# Distance to train[64]: 0.7810249675906652
# Distance to train[65]: 2.293468988235943
# Distance to train[66]: 3.112876483254676
# Distance to train[67]: 3.0757112998459397
# Distance to train[68]: 2.9983328701129897
# Distance to train[69]: 3.023243291566195
# Distance to train[70]: 0.6403124237432846
# Distance to train[71]: 0.678232998312527
# Distance to train[72]: 3.228002478313795
# Distance to train[73]: 2.6795522013948525
# Distance to train[74]: 0.4358898943540677
# Distance to train[75]: 2.812472222085046
# Distance to train[76]: 3.4655446902326914
# Distance to train[77]: 1.4764823060233396
# Distance to train[78]: 3.2388269481403302
# Distance to train[79]: 0.7874007874011818
# Distance to train[80]: 3.1921779399024732
# Distance to train[81]: 0.9695359714832656
# Distance to train[82]: 3.2526911934581184
# Distance to train[83]: 3.215587038162706
# Distance to train[84]: 3.0413812651491097
# Distance to train[85]: 3.014962686336267
# Distance to train[86]: 2.541653005427767
# Distance to train[87]: 3.0708305065568178
# Distance to train[88]: 2.042057785666213
# Distance to train[89]: 0.4123105625617654
# Distance to train[90]: 0.34641016151377524
# Distance to train[91]: 0.7348469228349531
# Distance to train[92]: 1.7146428199482247
# Distance to train[93]: 1.6852299546352718
# Distance to train[94]: 0.9899494936611669
# Distance to train[95]: 1.2489995996796799
# Distance to train[96]: 2.8670542373662897
# Distance to train[97]: 0.8366600265340753
# Distance to train[98]: 2.0542638584174138
# Distance to train[99]: 1.292284798332008
# Distance to train[100]: 2.9698484809834995
# Distance to train[101]: 0.7874007874011809
# Distance to train[102]: 0.5477225575051662
# Distance to train[103]: 1.0440306508910548
# Distance to train[104]: 0.6708203932499373
# Distance to train[105]: 3.0577769702841313
# Distance to train[106]: 2.9782545223670858
# Distance to train[107]: 3.0364452901377947
# Distance to train[108]: 1.691153452528776
# Distance to train[109]: 0.44721359549995765
# Distance to train[110]: 3.414674215792775
# Distance to train[111]: 3.2218007387174024
# K-nearest: [(90, 0.34641016151377524), (1, 0.3741657386773939), (0, 0.3999999999999998)]
# Nearest Labels: [np.int64(1), np.int64(1), np.int64(1)]
# Counts: [0 3]
# ...
# Distance to train[78]: 1.9824227601599014
# Distance to train[79]: 1.5033296378372905
# Distance to train[80]: 4.93457191659013
# Distance to train[81]: 1.0000000000000002
# Distance to train[82]: 5.015974481593781
# Distance to train[83]: 1.7146428199482249
# Distance to train[84]: 4.8072861366887665
# Distance to train[85]: 4.801041553663121
# Distance to train[86]: 1.1575836902790226
# Distance to train[87]: 4.8836461788299115
# Distance to train[88]: 0.640312423743285
# Distance to train[89]: 1.8841443681416772
# Distance to train[90]: 2.0639767440550294
# Distance to train[91]: 2.5258661880630173
# Distance to train[92]: 0.5099019513592786
# Distance to train[93]: 0.5477225575051656
# Distance to train[94]: 1.039230484541326
# Distance to train[95]: 0.8602325267042625
# Distance to train[96]: 4.690415759823429
# Distance to train[97]: 2.4535688292770597
# Distance to train[98]: 0.469041575982343
# Distance to train[99]: 0.8426149773176362
# Distance to train[100]: 4.781213235152768
# Distance to train[101]: 1.3638181696985856
# Distance to train[102]: 1.9339079605813718
# Distance to train[103]: 1.1
# Distance to train[104]: 1.5842979517754856
# Distance to train[105]: 4.87749935930288
# Distance to train[106]: 4.748684028233506
# Distance to train[107]: 4.853864439804639
# Distance to train[108]: 0.4242640687119288
# Distance to train[109]: 2.014944167960989
# Distance to train[110]: 1.97484176581315
# Distance to train[111]: 5.0039984012787215
# K-nearest: [(48, 0.10000000000000009), (47, 0.30000000000000016), (108, 0.4242640687119288)]
# Nearest Labels: [np.int64(2), np.int64(2), np.int64(2)]
# Counts: [0 0 3]
# Distance to train[0]: 0.8246211251235324
# Distance to train[1]: 0.6480740698407857
# Distance to train[2]: 2.3874672772626644
# Distance to train[3]: 2.949576240750525
# Distance to train[4]: 2.3021728866442674
# Distance to train[5]: 2.570992026436488
# Distance to train[6]: 2.8705400188814645
# Distance to train[7]: 0.9219544457292888
# Distance to train[8]: 2.1213203435596424
# Distance to train[9]: 2.6570660511172846
# Distance to train[10]: 1.452583904633395
# Distance to train[11]: 2.4617067250182343
# Distance to train[12]: 0.53851648071345
# Distance to train[13]: 3.4626579386361565
# Distance to train[14]: 1.5
# Distance to train[15]: 0.5291502622129182
# Distance to train[16]: 1.5394804318340654
# Distance to train[17]: 1.6340134638368187
# Distance to train[18]: 0.7615773105863909
# Distance to train[19]: 1.6462077633154326
# Distance to train[20]: 2.0322401432901573
# Distance to train[21]: 1.9570385790780929
# Distance to train[22]: 1.236931687685298
# Distance to train[23]: 2.6551836094703507
# Distance to train[24]: 1.4317821063276348
# Distance to train[25]: 0.5099019513592782
# Distance to train[26]: 0.5477225575051655
# Distance to train[27]: 0.38729833462074165
# Distance to train[28]: 1.178982612255159
# Distance to train[29]: 2.9698484809834995
# Distance to train[30]: 2.8653097563788807
# Distance to train[31]: 3.2295510523910282
# Distance to train[32]: 1.91049731745428
# Distance to train[33]: 0.6855654600401044
# Distance to train[34]: 2.6095976701399777
# Distance to train[35]: 3.1464265445104544
# Distance to train[36]: 2.014944167960989
# Distance to train[37]: 2.778488797889961
# Distance to train[38]: 1.4764823060233399
# Distance to train[39]: 0.9746794344808964
# Distance to train[40]: 2.882707061079915
# Distance to train[41]: 1.2727922061357855
# Distance to train[42]: 3.295451410656816
# Distance to train[43]: 0.6244997998398398
# Distance to train[44]: 2.861817604250837
# Distance to train[45]: 2.8618176042508368
# Distance to train[46]: 2.6814175355583845
# Distance to train[47]: 2.455605831561735
# Distance to train[48]: 2.1977260975835913
# Distance to train[49]: 2.819574435974337
# Distance to train[50]: 2.7166155414412247
# Distance to train[51]: 1.9339079605813716
# Distance to train[52]: 2.5179356624028344
# Distance to train[53]: 2.9359836511806394
# Distance to train[54]: 2.1330729007701543
# Distance to train[55]: 2.8053520278211073
# Distance to train[56]: 1.3638181696985858
# Distance to train[57]: 2.4062418831031933
# Distance to train[58]: 3.0149626863362666
# Distance to train[59]: 2.922327839240491
# Distance to train[60]: 2.782085548648711
# Distance to train[61]: 2.8478061731796283
# Distance to train[62]: 2.9883105594967865
# Distance to train[63]: 2.7055498516937364
# Distance to train[64]: 0.5196152422706634
# Distance to train[65]: 2.760434748368452
# Distance to train[66]: 3.6918829883949456
# Distance to train[67]: 2.8879058156387307
# Distance to train[68]: 2.729468812791236
# Distance to train[69]: 2.8600699292150185
# Distance to train[70]: 0.7937253933193772
# Distance to train[71]: 1.5165750888103098
# Distance to train[72]: 3.0033314835362415
# Distance to train[73]: 2.453568829277059
# Distance to train[74]: 1.2845232578665131
# Distance to train[75]: 2.6999999999999997
# Distance to train[76]: 4.008740450565489
# Distance to train[77]: 0.8366600265340757
# Distance to train[78]: 3.8871583451153624
# Distance to train[79]: 1.6309506430300091
# Distance to train[80]: 3.0675723300355933
# Distance to train[81]: 1.3038404810405295
# Distance to train[82]: 3.283291031876401
# Distance to train[83]: 3.8026306683663096
# Distance to train[84]: 2.8618176042508368
# Distance to train[85]: 2.68886593194975
# Distance to train[86]: 3.1527765540868895
# Distance to train[87]: 2.844292530665578
# Distance to train[88]: 2.364318083507378
# Distance to train[89]: 0.556776436283002
# Distance to train[90]: 0.6324555320336755
# Distance to train[91]: 0.7615773105863908
# Distance to train[92]: 2.1118712081942874
# Distance to train[93]: 2.2
# Distance to train[94]: 1.503329637837291
# Distance to train[95]: 1.9078784028338915
# Distance to train[96]: 2.619160170741759
# Distance to train[97]: 0.6164414002968976
# Distance to train[98]: 2.5099800796022262
# Distance to train[99]: 1.4317821063276348
# Distance to train[100]: 2.7748873851023212
# Distance to train[101]: 1.581138830084189
# Distance to train[102]: 0.5477225575051655
# Distance to train[103]: 1.307669683062202
# Distance to train[104]: 1.2767145334803702
# Distance to train[105]: 2.9883105594967865
# Distance to train[106]: 2.787471972953271
# Distance to train[107]: 2.7748873851023212
# Distance to train[108]: 2.0736441353327715
# Distance to train[109]: 0.7483314773547879
# Distance to train[110]: 3.992492955535426
# Distance to train[111]: 2.8809720581775866
# K-nearest: [(27, 0.38729833462074165), (25, 0.5099019513592782), (64, 0.5196152422706634)]
# Nearest Labels: [np.int64(1), np.int64(1), np.int64(1)]
# Counts: [0 3]
# Distance to train[0]: 2.8930952282978866
# Distance to train[1]: 2.7477263328068164
# Distance to train[2]: 4.41927595879687
# Distance to train[3]: 1.236931687685298
# Distance to train[4]: 4.182104733265296
# Distance to train[5]: 0.8246211251235321
# Distance to train[6]: 0.3872983346207414
# Distance to train[7]: 2.7313000567495322
# Distance to train[8]: 4.2391036788453285
# Distance to train[9]: 4.7
# Distance to train[10]: 3.870400496072725
# Distance to train[11]: 4.663689526544407
# Distance to train[12]: 2.6795522013948525
# Distance to train[13]: 5.291502622129181
# Distance to train[14]: 3.361547262794322
# Distance to train[15]: 2.6551836094703507
# Distance to train[16]: 3.7496666518505353
# Distance to train[17]: 3.7894590642992827
# Distance to train[18]: 3.4828149534536
# Distance to train[19]: 3.937003937005905
# Distance to train[20]: 3.5014282800023193
# Distance to train[21]: 4.052159917870962
# Distance to train[22]: 3.127299154222378
# Distance to train[23]: 1.1489125293076057
# Distance to train[24]: 3.9166312055132275
# Distance to train[25]: 2.9103264421710495
# Distance to train[26]: 2.3302360395462087
# Distance to train[27]: 2.831960451701259
# Distance to train[28]: 3.228002478313794
# Distance to train[29]: 4.832183771339827
# Distance to train[30]: 0.4690415759823432
# Distance to train[31]: 1.7320508075688774
# Distance to train[32]: 4.149698784249285
# Distance to train[33]: 2.7748873851023212
# Distance to train[34]: 0.5099019513592783
# Distance to train[35]: 0.6403124237432853
# Distance to train[36]: 3.6891733491393435
# Distance to train[37]: 1.3228756555322956
# Distance to train[38]: 3.8065732621348554
# Distance to train[39]: 2.0928449536456353
# Distance to train[40]: 1.2083045973594577
# Distance to train[41]: 3.4770677301427413
# Distance to train[42]: 5.146843692983108
# Distance to train[43]: 2.8390139133156778
# Distance to train[44]: 1.2569805089976536
# Distance to train[45]: 4.845616575834287
# Distance to train[46]: 4.669047011971501
# Distance to train[47]: 4.658325879540846
# Distance to train[48]: 4.465422712353221
# Distance to train[49]: 0.6164414002968981
# Distance to train[50]: 0.9949874371066203
# Distance to train[51]: 3.930648801406709
# Distance to train[52]: 4.5265881191025095
# Distance to train[53]: 1.9621416870348585
# Distance to train[54]: 4.25440947723653
# Distance to train[55]: 1.1747340124470727
# Distance to train[56]: 3.9331920878594273
# Distance to train[57]: 4.342810150121693
# Distance to train[58]: 1.4899664425751336
# Distance to train[59]: 0.7937253933193772
# Distance to train[60]: 4.624932431938871
# Distance to train[61]: 0.7348469228349538
# Distance to train[62]: 1.5811388300841895
# Distance to train[63]: 0.3316624790355398
# Distance to train[64]: 2.929163703175362
# Distance to train[65]: 4.817675788178362
# Distance to train[66]: 5.612486080160911
# Distance to train[67]: 0.7416198487095667
# Distance to train[68]: 1.0862780491200212
# Distance to train[69]: 0.714142842854285
# Distance to train[70]: 3.1368774282716245
# Distance to train[71]: 3.154362059117501
# Distance to train[72]: 1.0535653752852738
# Distance to train[73]: 0.8062257748298554
# Distance to train[74]: 3.009983388658482
# Distance to train[75]: 0.547722557505166
# Distance to train[76]: 6.039867548216599
# Distance to train[77]: 2.3769728648009423
# Distance to train[78]: 5.460769176590419
# Distance to train[79]: 3.160696125855822
# Distance to train[80]: 0.648074069840786
# Distance to train[81]: 3.548238999842034
# Distance to train[82]: 0.5567764362830022
# Distance to train[83]: 5.734980383575867
# Distance to train[84]: 0.6324555320336763
# Distance to train[85]: 1.1747340124470729
# Distance to train[86]: 5.080354318352215
# Distance to train[87]: 0.9165151389911681
# Distance to train[88]: 4.4877611344633745
# Distance to train[89]: 2.785677655436823
# Distance to train[90]: 2.6210684844162313
# Distance to train[91]: 2.2737634001804143
# Distance to train[92]: 4.220189569201838
# Distance to train[93]: 4.2296571965113205
# Distance to train[94]: 3.7054014627297813
# Distance to train[95]: 3.806573262134856
# Distance to train[96]: 1.0723805294763609
# Distance to train[97]: 2.5475478405713994
# Distance to train[98]: 4.594562003064056
# Distance to train[99]: 3.9166312055132275
# Distance to train[100]: 0.7549834435270754
# Distance to train[101]: 3.3211443810831223
# Distance to train[102]: 2.7221315177632395
# Distance to train[103]: 3.5014282800023193
# Distance to train[104]: 3.301514803843835
# Distance to train[105]: 0.547722557505166
# Distance to train[106]: 0.6480740698407864
# Distance to train[107]: 1.0999999999999996
# Distance to train[108]: 4.316248370981447
# Distance to train[109]: 2.7331300737432884
# Distance to train[110]: 5.710516614107695
# Distance to train[111]: 1.292284798332009
# K-nearest: [(63, 0.3316624790355398), (6, 0.3872983346207414), (30, 0.4690415759823432)]
# Nearest Labels: [np.int64(0), np.int64(0), np.int64(0)]
# Counts: [3]
# Distance to train[0]: 0.9591663046625434
# Distance to train[1]: 1.1916375287812984
# Distance to train[2]: 1.0677078252031311
# Distance to train[3]: 4.282522621072771
# Distance to train[4]: 1.208304597359457
# Distance to train[5]: 3.8587562763149474
# Distance to train[6]: 4.034848200366402
# Distance to train[7]: 2.1
# Distance to train[8]: 0.7348469228349536
# Distance to train[9]: 1.4212670403551897
# Distance to train[10]: 0.5196152422706631
# Distance to train[11]: 1.0295630140987002
# Distance to train[12]: 1.3747727084867518
# Distance to train[13]: 2.1142374511865976
# Distance to train[14]: 0.7810249675906648
# Distance to train[15]: 1.5099668870541498
# Distance to train[16]: 0.4123105625617656
# Distance to train[17]: 0.33166247903553975
# Distance to train[18]: 1.2727922061357853
# Distance to train[19]: 0.47958315233127174
# Distance to train[20]: 1.2041594578792294
# Distance to train[21]: 0.714142842854285
# Distance to train[22]: 0.9219544457292883
# Distance to train[23]: 3.976179070414208
# Distance to train[24]: 0.36055512754639885
# Distance to train[25]: 1.0295630140986998
# Distance to train[26]: 1.5937377450509222
# Distance to train[27]: 1.2609520212918488
# Distance to train[28]: 0.6244997998398398
# Distance to train[29]: 1.5937377450509231
# Distance to train[30]: 4.050925820105818
# Distance to train[31]: 4.607602413403308
# Distance to train[32]: 0.5385164807134507
# Distance to train[33]: 1.0723805294763604
# Distance to train[34]: 3.7907782842049724
# Distance to train[35]: 4.168932717135166
# Distance to train[36]: 1.009950493836208
# Distance to train[37]: 4.127953488110059
# Distance to train[38]: 0.3741657386773939
# Distance to train[39]: 2.3473389188611002
# Distance to train[40]: 4.222558466143482
# Distance to train[41]: 0.8124038404635958
# Distance to train[42]: 2.0149441679609885
# Distance to train[43]: 1.0148891565092215
# Distance to train[44]: 4.179712908801274
# Distance to train[45]: 1.4798648586948744
# Distance to train[46]: 1.3820274961085257
# Distance to train[47]: 1.0908712114635715
# Distance to train[48]: 0.8185352771872452
# Distance to train[49]: 4.028647415696737
# Distance to train[50]: 4.017461885320133
# Distance to train[51]: 0.812403840463596
# Distance to train[52]: 1.2083045973594575
# Distance to train[53]: 4.305810028322197
# Distance to train[54]: 1.0535653752852738
# Distance to train[55]: 4.117037770047781
# Distance to train[56]: 0.547722557505166
# Distance to train[57]: 1.1445523142259602
# Distance to train[58]: 4.382921400162225
# Distance to train[59]: 4.178516483155236
# Distance to train[60]: 1.4212670403551897
# Distance to train[61]: 4.102438299353203
# Distance to train[62]: 4.364630568559039
# Distance to train[63]: 3.8470768123342682
# Distance to train[64]: 1.3076696830622019
# Distance to train[65]: 1.42126704035519
# Distance to train[66]: 2.269361143582043
# Distance to train[67]: 4.135214625627067
# Distance to train[68]: 4.036087214122113
# Distance to train[69]: 4.096339829652808
# Distance to train[70]: 0.7416198487095659
# Distance to train[71]: 0.9899494936611658
# Distance to train[72]: 4.291852746774986
# Distance to train[73]: 3.7336309405188937
# Distance to train[74]: 0.9643650760992954
# Distance to train[75]: 3.905124837953327
# Distance to train[76]: 2.574878637916747
# Distance to train[77]: 2.213594362117865
# Distance to train[78]: 2.5826343140289922
# Distance to train[79]: 1.0862780491200212
# Distance to train[80]: 4.220189569201838
# Distance to train[81]: 0.4690415759823427
# Distance to train[82]: 4.347413023856831
# Distance to train[83]: 2.37065391822594
# Distance to train[84]: 4.0828911325187205
# Distance to train[85]: 4.018706259482023
# Distance to train[86]: 1.7492855684535904
# Distance to train[87]: 4.124318125460256
# Distance to train[88]: 1.2124355652982137
# Distance to train[89]: 1.0908712114635715
# Distance to train[90]: 1.2806248474865696
# Distance to train[91]: 1.7378147196982765
# Distance to train[92]: 0.9695359714832658
# Distance to train[93]: 1.0392304845413263
# Distance to train[94]: 0.4242640687119282
# Distance to train[95]: 0.7745966692414835
# Distance to train[96]: 3.9115214431215892
# Distance to train[97]: 1.6309506430300085
# Distance to train[98]: 1.2409673645990855
# Distance to train[99]: 0.36055512754639885
# Distance to train[100]: 4.0274061131204535
# Distance to train[101]: 0.8602325267042624
# Distance to train[102]: 1.1575836902790226
# Distance to train[103]: 0.6244997998398397
# Distance to train[104]: 0.9110433579144295
# Distance to train[105]: 4.158124577258358
# Distance to train[106]: 4.026164427839479
# Distance to train[107]: 4.071854614300467
# Distance to train[108]: 0.6480740698407859
# Distance to train[109]: 1.1832159566199232
# Distance to train[110]: 2.6495282598983545
# Distance to train[111]: 4.226109321823087
# K-nearest: [(17, 0.33166247903553975), (24, 0.36055512754639885), (99, 0.36055512754639885)]
# Nearest Labels: [np.int64(2), np.int64(2), np.int64(2)]
# Counts: [0 0 3]

# %% [markdown]
# Finally, the moment of truth! Test the accuracy of your predictions. In the cell below, complete the call to `accuracy_score()` by passing in `y_test` and `preds`!

# %%
print("Testing Accuracy: {}".format(accuracy_score(y_test, preds)))
# Expected Output: Testing Accuracy: 0.9736842105263158
# Out:
# Testing Accuracy: 0.9736842105263158

# %% [markdown]
# Over 97% accuracy! Not bad for a handwritten machine learning classifier!
#
# ## Summary
#
# That was great! Next, you'll dive a little deeper into evaluating performance of a KNN algorithm!
